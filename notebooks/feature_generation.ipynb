# %%
import random
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib.patches as mpatches

import sys
import os
sys.path.append(os.path.abspath('../utils'))
sys.path.append(os.path.abspath('../data'))
from preprocessing import Preprocessor
from features import FeaturesGenerator

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None)

# %%
# preprocessor = Preprocessor()

# zpp4 = preprocessor.zpp4_preprocessing()
# spec = preprocessor.spec_preprocessing()

# zpp4.to_csv('../data/processed_data/zpp4.csv', index=False)
# spec.to_csv('../data/processed_data/specs.csv', index=False)

# %%
zpp4 = pd.read_csv('../data/processed_data/zpp4.csv')
spec = pd.read_csv('../data/processed_data/specs.csv')

# %%
feature_generator = FeaturesGenerator(spec, zpp4)
features = feature_generator.make_features_df()
transformed_features, features_list = feature_generator.transform_data(features)
# features.to_csv(args.processed_data_path + 'features.csv')
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 386/386 [00:50<00:00,  7.58it/s]

# %%
transformed_features
# Out:
#              date                       supplier supplier_status  \
# 0      2022-07-02    Кошевой С.Б. ИП Глава К(Ф)Х            СХТП
# 1      2022-07-02  Невежина Любовь Николаевна ИП            СХТП
# 2      2022-07-02                   ТД АРНЕМ ООО         Трейдер
# 3      2022-07-03                 АФ НАСТЮША ООО            СХТП
# 4      2022-07-03    Кошевой С.Б. ИП Глава К(Ф)Х            СХТП
# ...           ...                            ...             ...
# 287752 2023-07-21   Яновская С.И. ИП Глава К(Ф)Х            СХТП
# 287753 2023-07-21    Янченко М.А. ИП Глава К(Ф)Х            СХТП
# 287754 2023-07-21    Ярушина В.С. ИП Глава К(Ф)Х            СХТП
# 287755 2023-07-21     Яценко В.В. ИП Глава К(Ф)Х            СХТП
# 287756 2023-07-21      Яцкий И.В. ИП Глава К(Ф)Х            СХТП
#
#         bids_submitted  bids_contracted  bids_nocontracted      conv  \
# 0             0.000000         0.000000           0.665666  0.000000
# ...
