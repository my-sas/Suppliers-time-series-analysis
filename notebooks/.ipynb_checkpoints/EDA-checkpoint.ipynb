# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

import sys
import os
sys.path.append(os.path.abspath('..'))
from data.preprocessing import Preprocessor
from data.feature_generation import zpp4_agg_features, zpp4_embed_agg, spec_agg_features, zpp4_preporarion
from figures.plots import show_embeddings

pd.set_option('display.max_columns', None)

# import warnings
# warnings.filterwarnings('ignore')

# %%
"""
Загрузка данных
"""

# таблица со спецификациями
spec = pd.read_csv('../data/processed_data/specs.csv')
spec['spec_date'] = pd.to_datetime(spec['spec_date'], format='%Y-%m-%d')
spec['delivery_period_end'] = pd.to_datetime(spec['delivery_period_end'], format='%Y-%m-%d')

# таблица с доставками
zpp4 = pd.read_csv('../data/processed_data/zpp4.csv')
zpp4['date'] = pd.to_datetime(zpp4['date'], format='%Y-%m-%d')
zpp4['spec_date'] = pd.to_datetime(zpp4['spec_date'], format='%Y-%m-%d')

# %%
"""
Генерация фичей
"""

# фичи аггрегации
spec = zpp4_agg_features(spec, zpp4)

# фичи эмбеддинги
spec = zpp4_embed_agg(spec)

# агрегация из прошлых спецификаций
spec = spec_agg_features(spec)

# кумулятивные фичи поставок
zpp4 = zpp4_preporarion(zpp4, spec)

features = [['lateness', 'underweight', 'price_change'],
            [str(i) for i in range(16)],
            ['delivery_length', 'mean_delivery_length', 'delivery_length_diff', 'mean_volume', 'volume_diff', 'conversion']]
# Out:
# C:\Users\vanya\Documents\Programs\ITMO_Sber\data\feature_generation.py:28: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   return df.drop(trash_cols, 1)

# %%
spec.head(2)
# Out:
#              supplier  supplier_status  spec_date delivery_period_end  option  \
# 0  50 ЛЕТ ОКТЯБРЯ ООО              1.0 2022-12-19          2022-12-25    15.0
# 1  50 ЛЕТ ОКТЯБРЯ ООО              1.0 2023-01-24          2023-02-12    15.0
#
#    declared_price  consent_price  spec_price  volume_requested  \
# 0            25.5           25.0        25.0              40.0
# 1            27.5           27.5        27.5              50.0
#
#    volume_contracted  bids_submitted  bids_contracted  \
# 0               60.0             1.0              1.0
# 1               59.0             1.0              1.0
#
#                                           id  late  lateness  underweight  \
# 0  50 ЛЕТ ОКТЯБРЯ ООО_Юг Руси, АО_2022-12-19     0       NaN          NaN
# 1  50 ЛЕТ ОКТЯБРЯ ООО_Юг Руси, АО_2023-01-24     0       0.0          1.0
#
#    price_change         0         1         2         3         4         5  \
# 0           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1         -5.28 -0.343797 -0.207023  0.122023 -0.351381  0.709916 -0.152337
#
#           6        7        8         9       10        11        12  \
# 0       NaN      NaN      NaN       NaN      NaN       NaN       NaN
# 1 -0.610757  0.14691 -0.80265  0.722523 -0.47786 -0.424774  0.521571
#
#          13        14        15  delivery_length  mean_delivery_length  \
# 0       NaN       NaN       NaN                6                   NaN
# 1 -0.012061  0.157792  0.696974               19                   6.0
#
#    delivery_length_diff  mean_volume  volume_diff  conversion
# 0                   NaN          NaN          NaN         NaN
# 1                  13.0         40.0         10.0         1.0

# %%
zpp4.head(2)
# Out:
#         date                      supplier                      basis  \
# 0 2022-07-06  Рязанова А.В. ИП Глава К(Ф)Х  ЮР Валуйский МЭЗ ф-л, ООО
# 1 2022-07-12    Осипов Л.А. ИП Глава К(Ф)Х                Юг Руси, АО
#
#    spec_date  contract_price  estimated_price  contract_price1  \
# 0 2022-07-06            25.0            24.78             25.0
# 1 2022-07-12            25.0            24.68             25.0
#
#    estimated_price1  quantity       sum  price_change  \
# 0             24.78     27.44  679963.2         -0.88
# 1             24.55     31.43  771606.5         -1.80
#
#                                                   id delivery_period_end  \
# 0  Рязанова А.В. ИП Глава К(Ф)Х_ЮР Валуйский МЭЗ ...          2022-07-09
# 1  Осипов Л.А. ИП Глава К(Ф)Х_Юг Руси, АО_2022-07-12          2022-07-22
#
#    volume_contracted  lateness_percentage  weight_percentage
# 0               30.0                  0.0           0.914667
# 1              170.0                  0.0           0.184882

# %% [markdown]
# ## Анализ таблицы ЦК

# %%
sns.histplot(data=spec, x='spec_date', hue='bids_contracted', multiple='stack').set(
    title='Распределение количества спецификаций по временной оси')
plt.legend(title='Законтрактовано', labels=['Да', 'Нет'])
# plt.savefig('../figures/some_EDA1.jpg', bbox_inches='tight')

# %%
sns.histplot(x=spec['spec_date'], hue=spec.isna().any(axis=1), multiple='stack').set(
    title='Распределение количества спецификаций по временной оси')
plt.legend(title='Первая спецификация', labels=['Да', 'Нет'])
# plt.savefig('../figures/some_EDA1.jpg', bbox_inches='tight')

# %%
sns.histplot(spec['spec_date'].map(lambda x: x.weekday())).set(title='Распределение спецификаций по дням недели', xlabel='')
plt.show()

# %%
sns.boxplot(x=spec['spec_date'].map(lambda x: x.weekday()), y = spec['volume_requested'], showfliers=False).set(title='Запрашиваемое количество сырья по дням недели', xlabel='')
plt.show()

# %% [markdown]
# ## Анализ таблицы ZPP4

# %%
history = zpp4[zpp4['id'] == zpp4['id'].unique()[133]]
x = history['lateness_percentage'].values
y = history['weight_percentage'].values
annotation = history['price_change'].values

# plot settings
plt.figure(figsize=(9, 6))
plt.xlabel('Время до конца спецификации')
plt.ylabel('Процент доставленного сырья')
plt.title('Пример графика поставки')

plt.plot(x, y)

# scatter plot
d = max(abs(annotation.min()), annotation.max())
plt.scatter(x, y, c=annotation, cmap='bwr', vmin=-d, vmax=d)

# add cbar
cbar = plt.colorbar()
cbar.set_label('Отклонение от заявленного качества')

# plt.savefig('../figures/supplier_spec_history.jpg', bbox_inches='tight')

# %% [markdown]
# ## Анализ сгенерированных переменных

# %%
import matplotlib.patches as mpatches

# %%
def sas_embeddings(vectors, labels):
    # reduce dimensions with TSNE
    trans_vectors = TSNE(
        n_components=2, learning_rate='auto', init='random',
        perplexity=40, random_state=22
    ).fit_transform(vectors)

    patches = []
    unique_labels = np.unique(labels)
    for label in unique_labels:
        indexes = np.where(labels == label)[0]
        g = plt.scatter(
            trans_vectors[indexes, 0],
            trans_vectors[indexes, 1],
            alpha=0.2, linewidths=0,
        )
        label_color = g.get_facecolor()
        label_color[0, -1] = 1.
        patches.append(mpatches.Patch(color=label_color, label=label))
    plt.legend(handles=patches, title=labels.name)
    return

# %%
plt.title('Эмбеддинги поставщиков')
# temp_spec = spec.dropna()
sas_embeddings(temp_spec[features[1]], temp_spec['bids_contracted'])

# %%
cols = features[2] + ['bids_contracted']
shape_plot = len(cols)
mask = np.zeros((shape_plot, shape_plot))
mask[np.triu_indices_from(mask)] = True

sns.heatmap(spec[cols].corr(), cmap = 'coolwarm', annot = False, 
            mask=mask, vmin=-1, vmax=1).set(
    title='Матрица корреляций аггрегированных признаков\nпредыдущих поставок поставщиков'
            )

plt.savefig('../figures/correlation_matrix.jpg', bbox_inches='tight')
# plt.show()
