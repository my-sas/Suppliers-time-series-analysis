# %%
from tqdm import tqdm
import numpy as np
import pandas as pd

import torch
from torch.utils.data import DataLoader

# импортирую свои модули
import os
import sys
sys.path.append(os.path.abspath('..'))
from figures.plots import show_embeddings
from src.models import RepeatAutoencoder1
from data.dataloading import TimeSeriesDataset, SequenceLengthSampler, pad_collate

import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
spec_cols = ['supplier_status', 'volume_contracted', 'spec_price', 'delivery_period_lenght', ]
delivery_cols = ['price_change', 'lateness_percentage', 'weight_percentage']
time_cols = ['month', 'day', 'weekday']

data = pd.read_csv('../data/final_data/data.csv')
dataset = TimeSeriesDataset(data, spec_cols, delivery_cols, time_cols)

bucket_boundaries = [2, 4, 6, 7, 10, 15, 20, 30, 40, 60, 80, 100, 140]
lengths = [(i, len(item[1])) for i, item in enumerate(dataset)]
sampler = SequenceLengthSampler(lengths, bucket_boundaries, batch_size=16)

dataloader = DataLoader(dataset, collate_fn=pad_collate, batch_sampler=sampler)

# %%
model = RepeatAutoencoder1(3, 16, 3)

# %%
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.00001)

# %%
for epoch in range(100):
    accumulated_loss = []
    for i, (h, x, t) in enumerate(dataloader):
        output = model(x)
        loss = criterion(output, x)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        accumulated_loss.append(loss.item())
        if i % 100 == 0 and i != 0:
            print(np.mean(accumulated_loss))
            accumulated_loss = []

# %%
# torch.save(model.state_dict(), '../src/weights/ra1.pth')

# %%
plt.title('Сравнение предсказанного графика с реальным')
i = 12
plt.plot(x[i, :, -2], x[i, :, -1])
plt.plot(output[i, :, -2].detach(), output[i, :, -1].detach())

# %%
plt.title('Сравнение предсказанных фичей с реальныит по от')
i = 6
for feature in range(3):
    plt.plot(x[i, :, feature])
    plt.plot(output[i, :, feature].detach())
    plt.show()

# %%
plt.title('Предсказанные графики')
for i in range(len(output)):
    plt.plot(output[i, :, -2].detach(), output[i, :, -1].detach())

# %%
supplier_set = set(dataset.supplier[30:45])

indexes = np.where([
    (supplier in supplier_set) for supplier in dataset.supplier
])[0]

# %%
seqs = [dataset[i][1] for i in indexes]
suppliers = [dataset.supplier[i] for i in indexes]
embs = np.stack([model.encoder(seq.unsqueeze(0))[1][0].squeeze().detach().numpy() for seq in seqs])

# %%
plt.title('Отображение эмбеддингов поставок на двумерную плоскость')
show_embeddings(embs, suppliers)
# plt.savefig('../figures/tsne_spec_embedings.jpg', bbox_inches='tight')

# %%
"""
Собираем датасет с эмбеддингами поставок
"""

embed_df = pd.DataFrame(columns = ['spec_id', 'supplier', 'date'] +
                        [f'{i}' for i in range(model.encoder.hidden_size)])
for i, (h, x, t) in tqdm(enumerate(dataset)):
    _, (embed, _) = model.encoder(x.unsqueeze(0))
    embed[-1, 0]
    
    embed = embed[-1, 0].detach().tolist()
    spec_data = [dataset.specs[i], dataset.supplier[i], dataset.specs_date[i]]
    
    embed_df.loc[len(embed_df)] = spec_data + embed
# Out:
# 2840it [00:18, 155.72it/s]

# %%
embed_df.to_csv('../data/final_data/embed_df.csv', index=False)

# %%
embed_df
# Out:
#                                                 spec_id  \
# 0     Рязанова А.В. ИП Глава К(Ф)Х_ЮР Валуйский МЭЗ ...
# 1     Осипов Л.А. ИП Глава К(Ф)Х_Юг Руси, АО_2022-07-12
# 2                       ЛЕТО ООО_Юг Руси, АО_2022-07-15
# 3        ФОГОР ООО_ЮР Валуйский МЭЗ ф-л, ООО_2022-07-15
# 4          КМЗ ООО_ЮР Лабинский МЭЗ ф-л, ООО_2022-07-15
# ...                                                 ...
# 2835  Тарадин П.В. ИП Глава К(Ф)Х_Юг Руси, АО_2023-0...
# 2836                   МАЛТА ООО_Юг Руси, АО_2023-07-18
# 2837   АО "ОРЛИК"_ЮР Чернянский МЭЗ ф-л, ООО_2023-07-13
# 2838   Бойко А.Н. ИП Глава К(Ф)Х_Юг Руси, АО_2023-07-18
# 2839  Харламов П.С. ИП Глава К(Ф)Х_Юг Руси, АО_2023-...
#
#                           supplier        date         0         1         2  \
# 0     Рязанова А.В. ИП Глава К(Ф)Х  2022-07-06  0.012422 -0.152277 -0.371495
# 1       Осипов Л.А. ИП Глава К(Ф)Х  2022-07-20  0.306000 -0.582370 -0.616625
# 2                         ЛЕТО ООО  2022-07-15 -0.366287 -0.675056 -0.630792
# 3                        ФОГОР ООО  2022-08-04  0.742277 -0.615772 -0.792042
# 4                          КМЗ ООО  2022-07-20  0.005684 -0.538214 -0.290365
# ...                            ...         ...       ...       ...       ...
# 2835   Тарадин П.В. ИП Глава К(Ф)Х  2023-07-17 -0.016311 -0.222170 -0.392144
# 2836                     МАЛТА ООО  2023-07-19 -0.053196 -0.606125 -0.636731
# 2837                    АО "ОРЛИК"  2023-07-18  0.687714 -0.591697 -0.793075
# 2838     Бойко А.Н. ИП Глава К(Ф)Х  2023-07-19  0.023297 -0.044501 -0.273752
# 2839  Харламов П.С. ИП Глава К(Ф)Х  2023-07-19  0.025713 -0.039625 -0.272842
#
#              3         4         5         6         7         8         9  \
# 0     0.345143  0.234435 -0.347446  0.003021 -0.117278  0.156940 -0.267533
# 1     0.449130  0.555506 -0.703764 -0.839743 -0.395974  0.175395 -0.431890
# 2     0.633663 -0.006006 -0.461123 -0.747989 -0.136140 -0.194559 -0.545033
# 3     0.433353  0.563646 -0.716965 -0.892410 -0.419208 -0.078329 -0.267952
# 4     0.430496  0.503456 -0.662543 -0.799338 -0.331622 -0.137794 -0.256638
# ...        ...       ...       ...       ...       ...       ...       ...
# 2835  0.378869  0.220391 -0.338987 -0.058076 -0.112331  0.155801 -0.295844
# 2836  0.486891  0.407064 -0.690421 -0.769649 -0.372844  0.017724 -0.361021
# 2837  0.381318  0.510884 -0.698315 -0.795494 -0.458381  0.494312 -0.269386
# 2838  0.268536  0.246139 -0.349387 -0.007314 -0.122238  0.111458 -0.241894
# 2839  0.265779  0.247363 -0.349736 -0.001879 -0.122321  0.112393 -0.239632
#
#             10        11        12        13        14        15
# 0     0.166429  0.015203 -0.192737  0.055639 -0.065744  0.213519
# 1     0.684241 -0.742406 -0.344925 -0.425448 -0.146025  0.416976
# 2     0.132576 -0.668419 -0.278661  0.050823 -0.421348  0.698584
# 3     0.711899 -0.835687 -0.256154 -0.548783 -0.107930  0.419491
# 4     0.667961 -0.754032 -0.218329 -0.442572 -0.237198  0.490091
# ...        ...       ...       ...       ...       ...       ...
# 2835  0.152295 -0.027652 -0.197853  0.079539 -0.084171  0.263750
# 2836  0.586234 -0.740126 -0.205809 -0.330123 -0.261101  0.529777
# 2837  0.637012 -0.755800 -0.250223 -0.400449 -0.082642  0.271193
# 2838  0.180564  0.011829 -0.207939  0.007469 -0.044945  0.168828
# 2839  0.181368  0.015740 -0.207702  0.006520 -0.043575  0.164490
#
# [2840 rows x 19 columns]
